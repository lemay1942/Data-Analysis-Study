# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import time

# %%
driver = wb.Chrome()

url = "https://sports.news.naver.com/kbaseball/record/index.nhn?category=kbo"
driver.get(url)
driver.page_source
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="ko"><!-- TODO 프레임 분리 --><head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n    <meta name="viewport" content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" />\n    <meta property="og:image" content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" />\n    <meta property="og:title" content="네이버 스포츠" />\n    <meta property="og:description" content="스포츠의 시작과 끝!" />\n    <meta property="og:url" content="sports.news.naver.com/kbaseball/record/index.nhn?category=kbo&amp;tab=team" />\n    \n        \n        \n        \n            <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.sports/resources/pc/2019/04/18/134234/css/common_loose_new.css" />\n\n            <link rel="stylesheet" 
# ...

# %%
soup = bs(driver.page_source,'html.parser')
team = soup.select('.tm')
shift = soup.select('#regularTeamRecordList_table > tr > td > strong')

# %%
shift
# Out:
# [<strong>0.680</strong>,
#  <strong>0.625</strong>,
#  <strong>0.560</strong>,
#  <strong>0.560</strong>,
#  <strong>0.560</strong>,
#  <strong>0.440</strong>,
#  <strong>0.440</strong>,
#  <strong>0.400</strong>,
#  <strong>0.385</strong>,
#  <strong>0.348</strong>]

# %%
for i in range(len(team)):
    print('팀 이름: ' + team[i].text)
    print('승률 : ' + record[i].text)
    print('순위: ')
    print(i + 1)
    print('-'*40)
# Out:
# 팀 이름:
#
#
# 두산
#
#
# 승률 : 0.680
# 순위:
# 1
# ----------------------------------------
# 팀 이름:
#
#
# SK
#
#
# 승률 : 0.625
# 순위:
# 2
# ----------------------------------------
# 팀 이름:
#
#
# 키움
#
#
# 승률 : 0.560
# 순위:
# 3
# ----------------------------------------
# 팀 이름:
#
#
# LG
#
#
# 승률 : 0.560
# 순위:
# 4
# ----------------------------------------
# 팀 이름:
#
#
# NC
#
#
# 승률 : 0.560
# 순위:
# 5
# ----------------------------------------
# 팀 이름:
#
#
# 한화
#
#
# 승률 : 0.440
# 순위:
# 6
# ----------------------------------------
# 팀 이름:
#
#
# 롯데
#
#
# 승률 : 0.440
# 순위:
# 7
# ----------------------------------------
# 팀 이름:
#
#
# 삼성
#
#
# 승률 : 0.400
# 순위:
# 8
# ----------------------------------------
# 팀 이름:
#
#
# KT
#
#
# 승률 : 0.385
# 순위:
# 9
# ----------------------------------------
# 팀 이름:
#
#
# KIA
#
#
# 승률 : 0.348
# 순위:
# 10
# ----------------------------------------

# %%
import pandas as pd

# %%
teams =[]
ranks =[]
shifts =[]
for i in range(len(team)):
    teams.append(team[i].text.strip())
    shifts.append(shift[i].text)
    ranks.append(i+1)

# %%
data = {'팀 이름': teams, '순위': ranks, '승률': shifts}
df = pd.DataFrame(data)
df
# Out:
#   팀 이름  순위     승률
# 0   두산   1  0.680
# 1   SK   2  0.625
# 2   키움   3  0.560
# 3   LG   4  0.560
# 4   NC   5  0.560
# 5   한화   6  0.440
# 6   롯데   7  0.440
# 7   삼성   8  0.400
# 8   KT   9  0.385
# 9  KIA  10  0.348
